# %%
import os

# %%
for root, dirs, files in os.walk("I:\\Work\\Zettmage\\Data\\Work\\SampleRaw\\20211108174723\\"):
    for dir in dirs:
        #print(root+dir)
        for ch_root, ch_dirs, ch_files in os.walk(root+dir):
            i = 0
            for sFile in ch_files:
                i = i + 1
                if i <= 5:
                    continue
                strFile = root+dir+'\\'+sFile
                if os.path.exists(strFile):
                    root, extension = os.path.splitext(strFile)
                    if extension == '.raw' or extension == '.bin'
                        print(strFile)
                        os.remove(strFile)

# %%
for root, dirs, files in os.walk("I:\\Work\\Zettmage\\Data\\Work\\SampleRaw\\20211117151304\\"):
    i = 0
    for sFile in files:
        i = i + 1
        if i <= 5:
            continue
        strFile = root+'\\'+sFile
        if os.path.exists(strFile):
            froot, fextension = os.path.splitext(strFile)
            if fextension == '.raw' or fextension == '.bin':
                print(strFile)
                os.remove(strFile)
# Out:
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0005.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0006.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0007.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0008.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0009.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0010.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0011.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0012.raw
# I:\Work\Zettmage\Data\Work\SampleRaw\20211117151304\\FrameID0_W8000_H6000_20211117151304_P10_0013.raw
# ...
